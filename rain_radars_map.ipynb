# %% [markdown]
# <a href="https://colab.research.google.com/github/AmantayAbdurakhmanov/misc/blob/master/rain_radars_map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install geopandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # New Section

# %%
import folium
import pandas as pd
import numpy as np
import re
from pathlib import Path

# %%
pathlist = Path("/content/drive/My Drive/maps/74_pixels/").rglob('*.*')
rows_list = []
for path in pathlist:
     path_in_str = str(path)
     
     pix_num  = re.findall(r'\d+', path_in_str)[-1]

     coords = dict(pd.read_csv(path_in_str).loc[0,:])
     coords['num'] = pix_num
     rows_list.append(coords)

df = pd.DataFrame(rows_list, dtype = np.float) 
df['num'] = df['num'].astype('int')
df["group"] = ""
df["col"] = ""

# %%
list_group = ["NWB1", "NWB2", "NW1", "NW2", "NW3", "NW4", "SWB1", "SW1", "SW2", "SW3", "NEB1",	"NE1", "NE2", "NE3", "NE4", "NEB2", "SE1", "SE2", "SE3", "SEB1", "SEB2"]
list_col = ['#0000ff', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', '#e6194b']
list_grcol = list(zip(list_group, list_col))

# %%
df.loc[(df["num"]  == 1)|(df["num"]  == 2), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 10)|(df["num"]  == 11)|(df["num"]  == 19), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 8)|(df["num"]  == 9)|(df["num"]  == 17)|(df["num"]  == 18), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 6)|(df["num"]  == 7)|(df["num"]  == 15)|(df["num"]  == 16), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 26)|(df["num"]  == 27)|(df["num"]  == 34)|(df["num"]  == 35), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 24)|(df["num"]  == 25)|(df["num"]  == 32)|(df["num"]  == 33), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 3)|(df["num"]  == 12), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 4)|(df["num"]  == 5)|(df["num"]  == 13)|(df["num"]  == 14), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 22)|(df["num"]  == 23)|(df["num"]  == 30)|(df["num"]  == 31), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 20)|(df["num"]  == 21)|(df["num"]  == 28)|(df["num"]  == 29), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 45)|(df["num"]  == 55)|(df["num"]  == 63), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 43)|(df["num"]  == 44)|(df["num"]  == 53)|(df["num"]  == 54), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 41)|(df["num"]  == 42)|(df["num"]  == 51)|(df["num"]  == 52), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 61)|(df["num"]  == 62)|(df["num"]  == 68)|(df["num"]  == 69), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 59)|(df["num"]  == 60)|(df["num"]  == 66)|(df["num"]  == 67), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 72)|(df["num"]  == 73)|(df["num"]  == 74), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 37)|(df["num"]  == 38)|(df["num"]  == 47)|(df["num"]  == 48), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 39)|(df["num"]  == 40)|(df["num"]  == 49)|(df["num"]  == 50), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 57)|(df["num"]  == 58)|(df["num"]  == 64)|(df["num"]  == 65)|(df["num"]  == 56), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 36)|(df["num"]  == 46), ["group", "col"]] = list_grcol.pop(0)
df.loc[(df["num"]  == 70)|(df["num"]  == 71), ["group", "col"]] = list_grcol.pop(0)
df
# Out:
#         lat       lon  num group      col
# 0  -36.7569  174.7000   12  SWB1  #46f0f0
# 1  -36.7209  174.6937   11  NWB2  #3cb44b
# 2  -36.7254  174.6938   10  NWB2  #3cb44b
# 3  -36.7345  174.6884    1  NWB1  #0000ff
# 4  -36.7523  174.7055   22   SW2  #bcf60c
# ..      ...       ...  ...   ...      ...
# 69 -36.7294  174.7330   69   NE3  #fffac8
# 70 -36.7339  174.7331   68   NE3  #fffac8
# 71 -36.7384  174.7332   67   NE4  #800000
# 72 -36.7429  174.7333   66   NE4  #800000
# 73 -36.7298  174.7050   27   NW3  #f58231
#
# [74 rows x 5 columns]

# %%
shpFile = gpd.read_file("/content/drive/My Drive/maps/Oteha_shapefile/Oteha.shp")
shpFile  = shpFile.to_crs({'init': 'epsg:4269'})
shpFile.to_file("oteha.json", driver='GeoJSON')
# Out:
# /usr/local/lib/python3.6/dist-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
#@title Default title text
from typing import List
import folium as fl
import branca as bc
def add_categorical_legend(
    folium_map: fl.Map,
    title: str,
    colors: List[str],
    labels: List[str],
) -> fl.Map:
    """
    Given a Folium map, add to it a categorical legend with the given title, colors, and corresponding labels.
    The given colors and labels will be listed in the legend from top to bottom.
    Return the resulting map.
    
    Based on `this example <http://nbviewer.jupyter.org/gist/talbertc-usgs/18f8901fc98f109f2b71156cf3ac81cd>`_.
    """
    # Error check
    if len(colors) != len(labels):
        raise ValueError("colors and labels must have the same length.")

    color_by_label = dict(zip(labels, colors))

    # Make legend HTML
    template = f"""
    {{% macro html(this, kwargs) %}}

    <!doctype html>
    <html lang="en">
    <head>
      <meta charset="utf-8">
      <meta name="viewport" content="width=device-width, initial-scale=1">
    </head>
    <body>
    <div id='maplegend' class='maplegend'>
      <div class='legend-title'>{title}</div>
      <div class='legend-scale'>
        <ul class='legend-labels'>
    """

    for label, color in color_by_label.items():
        template += f"<li><span style='background:{color}'></span>{label}</li>"

    template += f"""
        </ul>
      </div>
    </div>

    </body>
    </html>

    <style type='text/css'>
      .maplegend {{
        position: absolute;
        z-index:9999;
        background-color: rgba(255, 255, 255, 1);
        border-radius: 5px;
        border: 2px solid #bbb;
        padding: 10px;
        font-size:12px;
        font-weight:bold;
        right: 10px;
        bottom: 20px;
      }}
      .maplegend .legend-title {{
        text-align: left;
        margin-bottom: 5px;
        font-weight: bold;
        font-size: 90%;
        }}
      .maplegend .legend-scale ul {{
        margin: 0;
        margin-bottom: 5px;
        padding: 0;
        float: left;
        list-style: none;
        }}
      .maplegend .legend-scale ul li {{
        font-size: 80%;
        list-style: none;
        margin-left: 0;
        line-height: 18px;
        margin-bottom: 2px;
        }}
      .maplegend ul.legend-labels li span {{
        display: block;
        float: left;
        height: 16px;
        width: 30px;
        margin-right: 5px;
        margin-left: 0;
        border: 0px solid #ccc;
        }}
      .maplegend .legend-source {{
        font-size: 80%;
        color: #777;
        clear: both;
        }}
      .maplegend a {{
        color: #777;
        }}
    </style>
    {{% endmacro %}}
    """

    macro = bc.element.MacroElement()
    macro._template = bc.element.Template(template)
    folium_map.get_root().add_child(macro)

    return folium_map

# %%
from folium.features import DivIcon
map_otahe = folium.Map(location=[df.lat.mean(), df.lon.mean()], tiles='cartodbpositron', zoom_start=13)
 
for lat, lon, num, group, col in zip(df['lat'], df['lon'], df['num'].astype('int'), df['group'], df['col']):
    num_str = f'{num}'
    label = folium.Popup(num_str, parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=10,
        popup=label,
        color=col,
        fill=True,
        fill_color=col,
        fill_opacity=0.7#,
        #parse_html=False
        ).add_to(map_otahe)  


    folium.Marker(
    [lat, lon],
    icon=DivIcon(
        html=f'<div style="font-size: 10pt; color : black">{num_str}</div>'
        )
    ).add_to(map_otahe)



    folium.Marker(
    [-36.7416, 174.71],
    icon=DivIcon(
        html=f'<div style="font-size: 12pt; color : black">7834</div>'
        )
    ).add_to(map_otahe)

    folium.Marker(
    [-36.7319368, 174.6948212],
    icon=DivIcon(
        html=f'<div style="font-size: 12pt; color : black">7811</div>'
        )
    ).add_to(map_otahe)

    folium.Marker(
    [-36.74759, 174.71563],
    icon=DivIcon(
        html=f'<div style="font-size: 12pt; color : black">647727</div>'
        )
    ).add_to(map_otahe)    



colors = list_col
colors.extend(["0","0","0"])

labels = list_group
labels.extend(["7834 - ACC - Level -Alexandra @ Rosedale Rd", 
                                           "7811 - ACC - Level -Oteha River @ Days Bridge", 
                                           "647727 - ACC - Rain -Oteha @ Rosedale Ponds"])

map_otahe = add_categorical_legend(map_otahe, "Category", 
                                   colors=colors, labels=labels)    


folium.GeoJson(
    (open('/content/oteha.json', "r").read()),
    name='geojson',
).add_to(map_otahe)

#map_otahe.fit_bounds(layer.get_bounds())  # 2. fit the map to GeoJSON layer 

#folium.LayerControl().add_to(map_otahe, line_color='Orange')


map_otahe
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from IPython.display import Image
Image(filename="/content/rain_radars.png")
