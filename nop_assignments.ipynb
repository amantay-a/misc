# %% [markdown]
# Install **PuLP** library for linear programming modelling

# %%
# !pip install pulp
# Out:
# Collecting pulp
#   Downloading PuLP-2.6.0-py3-none-any.whl (14.2 MB)
#      |████████████████████████████████| 14.2 MB 6.6 MB/s eta 0:00:01
# Installing collected packages: pulp
# Successfully installed pulp-2.6.0

# %% [markdown]
# Input DataFrame **in_df**

# %%
import pandas as pd
in_df = {'pr_id' : 1
        ,'pr_code' : 'ABC'
        ,'blockchain' : 'ethereum'
        ,'node_operator': ['anyblockAnalytics,omniscience,staked,ztake,TSystems,everstake,secureDataLinks,xbto,newRoad,wetez,prophet,huobi,validationCapital,dMakers,kaiko,syncnode,p2pOrg,blocksizeCapital,chorusOne,youbi,kyber,dexTrac,kytzu,inotel,linkForest,linkPool,simplyVC,figmentNetworks,cosmostation,vulcan,snzPool,easy2Stake,chainlayer,stakingFacilities,alphachain,frameworkVentures,infinityStones,onchainTech,stakeFish,01node,bHarvest,fiews']
        ,'ranking_score' : ['9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.57,9,5.57,8.86,4.89,4.3,9.14,8.86,8,8.3,6.7,7.14,9.75,8.57,9.7,10,10,9.75,8.29,8.43,8.14,8,8.29,10,9.57,9,9.88,3.7,7.38,7.14,9.43,7.14,10']
        ,'node_operator_id' : ['1,2,3,7,8,9,10,12,14,15,21,24,25,28,30,31,34,36,38,41,42,43,44,46,48,49,53,55,57,61,64,65,66,67,71,73,74,76,77,78,79,82']
        ,'target_mean':8.5
        ,'target_std' :1.25
        ,'oracles_num': 16
         ,'api' : ['coinapi,coingecko,coinmarketcap,nomics']
        ,'json_file' : ['operators-apis.json']
       }
in_df = pd.DataFrame(in_df)
display(in_df)
# Out:
#    pr_id pr_code blockchain  \
# 0      1     ABC   ethereum
#
#                                        node_operator  \
# 0  anyblockAnalytics,omniscience,staked,ztake,TSy...
#
#                                        ranking_score  \
# 0  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...
#
#                                     node_operator_id  target_mean  target_std  \
# 0  1,2,3,7,8,9,10,12,14,15,21,24,25,28,30,31,34,3...          8.5        1.25
#
#    oracles_num                                     api            json_file
# 0           16  coinapi,coingecko,coinmarketcap,nomics  operators-apis.json

# %% [markdown]
# Main Code

# %%
import numpy as np
import pandas as pd
import json
import pulp as lp

def get_whole_frame(operators_apis_json_path_or_buf):
    
    df = pd.read_json(operators_apis_json_path_or_buf)
    jfile = df.to_json()
    jfile = json.loads(jfile)

    d = {x: [jfile[x][y] for y in jfile[x] ] for x in jfile }
    d = {x:[z for y in d[x] if y for z in y if z] for x in d}
    d = json.dumps(d)
    df = pd.read_json(d, orient='index')
    df.columns = [1 for x in df.columns]
    df = df.reset_index()
    df = pd.melt(df, id_vars = 'index', value_name = 'operator').pivot_table(columns='operator', index = 'index', values='variable', aggfunc='max')


    return df

def get_operator_list(operator_str, ranking_str, operator_id_str, target_mean, target_deviation, n_samples):
    
    operator_id_list = operator_id_str.split(',')

    operator_list = operator_str.split(',')

    #split string to list and cast to float if not empty, otherwise set it to target mean
    ranking_list = list(map(lambda x: float(x) if x else target_mean, ranking_str.split(',')))
    #add small random number to shuffle equal ranks
    ranking_list = [x+np.random.normal(0, 10e-3) for x in ranking_list]

    trials_list = np.random.normal(target_mean, target_deviation, n_samples)
    #print(trials_list)
    operator_dict = dict(zip(operator_list, operator_id_list))
    ranking_dict_init = dict(zip(operator_list,ranking_list))
    ranking_dict = dict()
    
    #print(ranking_dict_init)
    for t in trials_list:
        if len(ranking_dict_init)>0:
            closest_ranking = min(ranking_dict_init.values(), key=lambda x:abs(float(x)-t))
            del_trial = list(ranking_dict_init.keys())[list(ranking_dict_init.values()).index(closest_ranking)]
            ranking_dict_init.pop(del_trial)
        
            ranking_dict[del_trial] = closest_ranking
        
            #print(f'trial {t}, closest val {closest_ranking}, del_trial {del_trial}')
        #print(ranking_dict_init,'\n')
        
    for i in ranking_dict_init:
        operator_dict.pop(i)
    
    return ranking_dict, operator_dict
    
def solve_it (df, operator_list, api_list, maxNum):
    if not maxNum:
        maxNum = np.floor(len(operator_list)/2)
        
    model = lp.LpProblem(name="assignment_problem", sense=lp.LpMaximize)

    var = lp.LpVariable.dicts("op_to_api", ((i, j) for i, operator in enumerate(operator_list) for j, api in enumerate(api_list)),cat='Binary')

    model += lp.lpSum([var[i, j]*df.loc[operator,api] for i, operator in enumerate(operator_list) for j, api in enumerate(api_list)])

    for i, operator in enumerate(operator_list):
        model += (lp.lpSum([var[i, j]*df.loc[operator,api] for j, api in enumerate(api_list)]) == 3, "Triplet"+operator_list[i])
    for j, api in enumerate(api_list):
        model += (lp.lpSum([var[i, j]*df.loc[operator,api] for i, operator in enumerate(operator_list)]) >= maxNum, "Each Api"+api_list[j])
    
    #solver = lp.getSolver('PULP_CBC_CMD', timeLimit=10, logPath = 'D:\\pulp.log' ) 
    solver = lp.getSolver('PULP_CBC_CMD', timeLimit=10, msg = False) 
    model.solve(solver) 

    return model

def solve_optimum(df, operator_list, api_list, ignore_json = False):
    maxNumPerDataSource = int((len(operator_list)-1)/2)
    opt_std = 1
    if ignore_json:
        opt_std = 2
    opt_solution = pd.DataFrame()
    opt_model=''
    for maxNum in reversed(range(maxNumPerDataSource+1)):
        model = solve_it(df, operator_list, api_list,maxNum)

        if len(model.variables())<=1: #solution is empty
            continue

        df_answer = df.copy()
        for v in model.variables():
            i = int(v.name[v.name.index('(')+1:v.name.index(',')])
            j = int(v.name[v.name.index(',_')+2:v.name.index(')')])
            df_answer.iloc[i,j] = int(v.varValue)
        
        api_count_list = df_answer[df_answer.columns].sum()
        v_std = np.std(api_count_list)
        v_maxcnt  = np.max(api_count_list)
        #print(f'maxNum={maxNum}, v_std={v_std}, min = {df_answer.min().min()}, v_maxcnt = {v_maxcnt}')
        if min([v.varValue for v in model.variables()]) < 0:
            continue
        if v_std <=opt_std or (v_std < 1 and  v_maxcnt <= maxNumPerDataSource):
            opt_model = model
            opt_solution = df_answer
            opt_std = v_std
            #print(f'opt maxNum={maxNum}, v_std={v_std}')
            
    return opt_solution, opt_std

def try_it(row, df_whole, df_answer, ignore_json=False):
    api_list         = row['api'].split(',')
    

    ranking_dict, operator_dict = get_operator_list(row['node_operator'], row['ranking_score'], row['node_operator_id'], 
                                                    row['target_mean'],
                                                    row['target_std'],
                                                    row['oracles_num'])
    operator_list = list(ranking_dict.keys())
    ranking_list = list(ranking_dict.values())
    operator_id_list = list(operator_list)
    
    df = df_whole.reindex(operator_list).loc[operator_list, api_list].copy()
    df.fillna(0, inplace=True)
    df = df.astype(int)
    
    if ignore_json:
        df.loc[:,:] = 1

    if len(df)>0 and len(operator_id_list)>=row['oracles_num']:
        df_answer, std = solve_optimum(df, operator_list, api_list, ignore_json)
        df_answer = df_answer.mul(df_answer.columns, axis = 'columns')
        df_answer = df_answer.reset_index().melt(id_vars=['index'])
        if len(df_answer['value'].values)>0:
            df_answer = df_answer[df_answer['value'].values !='']
        df_answer = df_answer.drop(columns=['value'])
        df_answer.columns = ['operator','api']
    
    return df_answer, ranking_dict, operator_dict

#read operators-apis.json file    
#df_whole = get_whole_frame('D:\\operators-apis.json')
df_whole = get_whole_frame(in_df.loc[0,'json_file'])

out_df = pd.DataFrame()
i=0;
in_len = len(in_df)

for index, row in in_df.iterrows():
    i+=1
    pr_id = float(row['pr_id'])
    out_df.loc[len(out_df), ['pr_id','msg']] = [row['pr_id'], f'start']

    df_answer = pd.DataFrame()
    n_trials=0
    ignore_json = True #Ignoring operators-apis.json constraints from the very beginning https://app.asana.com/0/1199660287022808/1201468377285739/f
    while n_trials < 200: # 200 trials
        n_trials+=1
        df_answer = pd.DataFrame()
        
        if n_trials > 100: #trials from 100 to 200
            ignore_json = True #Ignore json from 100th trial: https://app.asana.com/0/1199613136501554/1200764619184594/f

        df_answer, ranking_dict, operator_dict = try_it(row, df_whole, df_answer, ignore_json)
        # Trial Details
        out_df.loc[len(out_df), ['pr_id','msg']] = [pr_id, f'end trial={n_trials}, ignore_json={ignore_json}, df_answer_len={len(df_answer)}, oracles={row["oracles_num"]}']
        if len(df_answer) == row['oracles_num']*3: # Success! Each NOp has 3 api assigned
            break
            

    if len(df_answer) == row['oracles_num']*3: #success
        df_answer['pr_id'] = pr_id
        df_answer['pr_code'] = row['pr_code']    
        df_answer['blockchain'] = row['blockchain']    
        df_answer['ranking_str'] = row['ranking_score']
        df_answer['ranking_score'] = df_answer['operator'].map(lambda x: ranking_dict[x])
        df_answer['operator_id'] = df_answer['operator'].map(lambda x: float(operator_dict[x]))
        df_answer['msg'] = 'OK'

        df_answer['comment'] = f'auto assigned with ignore_json={ignore_json} ({n_trials} random trials)'
        out_df = out_df.append(df_answer, ignore_index=True)

    comment = f'{i}, df_answer_len={len(df_answer)}, n_trials={n_trials}'
    out_df.loc[len(out_df), ['pr_id', 'msg', 'comment']] = [pr_id, 'end', comment]

# %%
display(out_df[out_df['msg']=='OK'].loc[:,['operator','api']].pivot(index = 'operator', columns='api', values = 'operator').apply(pd.notna).astype('int8'))
# Out:
# api                coinapi  coingecko  coinmarketcap  nomics
# operator
# 01node                   1          1              1       0
# anyblockAnalytics        1          1              0       1
# blocksizeCapital         1          0              1       1
# easy2Stake               1          0              1       1
# everstake                1          1              1       0
# fiews                    1          0              1       1
# frameworkVentures        1          0              1       1
# kytzu                    1          1              1       0
# linkPool                 1          1              1       0
# newRoad                  0          1              1       1
# onchainTech              0          1              1       1
# snzPool                  0          1              1       1
# stakeFish                1          1              1       0
# syncnode                 1          1              1       0
# vulcan                   1          1              0       1
# wetez                    0          1              1       1

# %%
display(out_df[out_df['msg']=='OK'].sort_values(by='operator').reset_index().loc[:,['pr_code','operator','api']])
# Out:
#    pr_code           operator            api
# 0      ABC             01node      coingecko
# 1      ABC             01node  coinmarketcap
# 2      ABC             01node        coinapi
# 3      ABC  anyblockAnalytics        coinapi
# 4      ABC  anyblockAnalytics      coingecko
# 5      ABC  anyblockAnalytics         nomics
# 6      ABC   blocksizeCapital        coinapi
# 7      ABC   blocksizeCapital  coinmarketcap
# 8      ABC   blocksizeCapital         nomics
# 9      ABC         easy2Stake  coinmarketcap
# 10     ABC         easy2Stake        coinapi
# 11     ABC         easy2Stake         nomics
# 12     ABC          everstake      coingecko
# 13     ABC          everstake        coinapi
# 14     ABC          everstake  coinmarketcap
# 15     ABC              fiews         nomics
# 16     ABC              fiews        coinapi
# 17     ABC              fiews  coinmarketcap
# 18     ABC  frameworkVentures        coinapi
# 19     ABC  frameworkVentures  coinmarketcap
# 20     ABC  frameworkVentures         nomics
# 21     ABC              kytzu  coinmarketcap
# 22     ABC              kytzu      coingecko
# 23     ABC              kytzu        coinapi
# 24     ABC           linkPool  coinmarketcap
# 25     ABC           linkPool        coinapi
# 26     ABC           linkPool      coingecko
# 27     ABC            newRoad         nomics
# 28     ABC            newRoad  coinmarketcap
# 29     ABC            newRoad      coingecko
# 30     ABC        onchainTech         nomics
# 31     ABC        onchainTech  coinmarketcap
# 32     ABC        onchainTech      coingecko
# 33     ABC            snzPool         nomics
# 34     ABC            snzPool  coinmarketcap
# 35     ABC            snzPool      coingecko
# 36     ABC          stakeFish      coingecko
# 37     ABC          stakeFish        coinapi
# 38     ABC          stakeFish  coinmarketcap
# 39     ABC           syncnode        coinapi
# 40     ABC           syncnode      coingecko
# 41     ABC           syncnode  coinmarketcap
# 42     ABC             vulcan         nomics
# 43     ABC             vulcan        coinapi
# 44     ABC             vulcan      coingecko
# 45     ABC              wetez      coingecko
# 46     ABC              wetez  coinmarketcap
# 47     ABC              wetez         nomics

# %%
display(out_df)
# Out:
#     pr_id                                                msg  \
# 0     1.0                                              start
# 1     1.0  end trial=1, ignore_json=True, df_answer_len=4...
# 2     1.0                                                 OK
# 3     1.0                                                 OK
# 4     1.0                                                 OK
# 5     1.0                                                 OK
# 6     1.0                                                 OK
# 7     1.0                                                 OK
# 8     1.0                                                 OK
# 9     1.0                                                 OK
# 10    1.0                                                 OK
# 11    1.0                                                 OK
# 12    1.0                                                 OK
# 13    1.0                                                 OK
# 14    1.0                                                 OK
# 15    1.0                                                 OK
# 16    1.0                                                 OK
# 17    1.0                                                 OK
# 18    1.0                                                 OK
# 19    1.0                                                 OK
# 20    1.0                                                 OK
# 21    1.0                                                 OK
# 22    1.0                                                 OK
# 23    1.0                                                 OK
# 24    1.0                                                 OK
# 25    1.0                                                 OK
# 26    1.0                                                 OK
# 27    1.0                                                 OK
# 28    1.0                                                 OK
# 29    1.0                                                 OK
# 30    1.0                                                 OK
# 31    1.0                                                 OK
# 32    1.0                                                 OK
# 33    1.0                                                 OK
# 34    1.0                                                 OK
# 35    1.0                                                 OK
# 36    1.0                                                 OK
# 37    1.0                                                 OK
# 38    1.0                                                 OK
# 39    1.0                                                 OK
# 40    1.0                                                 OK
# 41    1.0                                                 OK
# 42    1.0                                                 OK
# 43    1.0                                                 OK
# 44    1.0                                                 OK
# 45    1.0                                                 OK
# 46    1.0                                                 OK
# 47    1.0                                                 OK
# 48    1.0                                                 OK
# 49    1.0                                                 OK
# 50    1.0                                                end
#
#              operator            api pr_code blockchain  \
# 0                 NaN            NaN     NaN        NaN
# 1                 NaN            NaN     NaN        NaN
# 2            syncnode        coinapi     ABC   ethereum
# 3            linkPool        coinapi     ABC   ethereum
# 4               fiews        coinapi     ABC   ethereum
# 5           stakeFish        coinapi     ABC   ethereum
# 6               kytzu        coinapi     ABC   ethereum
# 7    blocksizeCapital        coinapi     ABC   ethereum
# 8              01node        coinapi     ABC   ethereum
# 9          easy2Stake        coinapi     ABC   ethereum
# 10          everstake        coinapi     ABC   ethereum
# 11  frameworkVentures        coinapi     ABC   ethereum
# 12  anyblockAnalytics        coinapi     ABC   ethereum
# 13             vulcan        coinapi     ABC   ethereum
# 14        onchainTech      coingecko     ABC   ethereum
# 15           syncnode      coingecko     ABC   ethereum
# 16           linkPool      coingecko     ABC   ethereum
# 17          stakeFish      coingecko     ABC   ethereum
# 18              kytzu      coingecko     ABC   ethereum
# 19            newRoad      coingecko     ABC   ethereum
# 20             01node      coingecko     ABC   ethereum
# 21            snzPool      coingecko     ABC   ethereum
# 22          everstake      coingecko     ABC   ethereum
# 23  anyblockAnalytics      coingecko     ABC   ethereum
# 24             vulcan      coingecko     ABC   ethereum
# 25              wetez      coingecko     ABC   ethereum
# 26        onchainTech  coinmarketcap     ABC   ethereum
# 27           syncnode  coinmarketcap     ABC   ethereum
# 28           linkPool  coinmarketcap     ABC   ethereum
# 29              fiews  coinmarketcap     ABC   ethereum
# 30          stakeFish  coinmarketcap     ABC   ethereum
# 31              kytzu  coinmarketcap     ABC   ethereum
# 32   blocksizeCapital  coinmarketcap     ABC   ethereum
# 33            newRoad  coinmarketcap     ABC   ethereum
# 34             01node  coinmarketcap     ABC   ethereum
# 35         easy2Stake  coinmarketcap     ABC   ethereum
# 36            snzPool  coinmarketcap     ABC   ethereum
# 37          everstake  coinmarketcap     ABC   ethereum
# 38  frameworkVentures  coinmarketcap     ABC   ethereum
# 39              wetez  coinmarketcap     ABC   ethereum
# 40        onchainTech         nomics     ABC   ethereum
# 41              fiews         nomics     ABC   ethereum
# 42   blocksizeCapital         nomics     ABC   ethereum
# 43            newRoad         nomics     ABC   ethereum
# 44         easy2Stake         nomics     ABC   ethereum
# 45            snzPool         nomics     ABC   ethereum
# 46  frameworkVentures         nomics     ABC   ethereum
# 47  anyblockAnalytics         nomics     ABC   ethereum
# 48             vulcan         nomics     ABC   ethereum
# 49              wetez         nomics     ABC   ethereum
# 50                NaN            NaN     NaN        NaN
#
#                                           ranking_str  ranking_score  \
# 0                                                 NaN            NaN
# 1                                                 NaN            NaN
# 2   9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.157908
# 3   9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...      10.014989
# 4   9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.994345
# 5   9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       7.143587
# 6   9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.565709
# 7   9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       7.993321
# 8   9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.453187
# 9   9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.283622
# 10  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.132663
# 11  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.874775
# 12  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.731863
# 13  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.149179
# 14  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       7.388646
# 15  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.157908
# 16  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...      10.014989
# 17  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       7.143587
# 18  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.565709
# 19  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.286218
# 20  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.453187
# 21  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.008597
# 22  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.132663
# 23  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.731863
# 24  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.149179
# 25  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.576973
# 26  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       7.388646
# 27  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.157908
# 28  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...      10.014989
# 29  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.994345
# 30  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       7.143587
# 31  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.565709
# 32  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       7.993321
# 33  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.286218
# 34  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.453187
# 35  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.283622
# 36  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.008597
# 37  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.132663
# 38  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.874775
# 39  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.576973
# 40  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       7.388646
# 41  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.994345
# 42  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       7.993321
# 43  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.286218
# 44  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.283622
# 45  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.008597
# 46  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.874775
# 47  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       9.731863
# 48  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.149179
# 49  9.75,8.86,8.29,8.88,8.43,8.14,4.38,10,9.29,8.5...       8.576973
# 50                                                NaN            NaN
#
#     operator_id                                            comment
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2          31.0  auto assigned with ignore_json=True (1 random ...
# 3          49.0  auto assigned with ignore_json=True (1 random ...
# 4          82.0  auto assigned with ignore_json=True (1 random ...
# 5          77.0  auto assigned with ignore_json=True (1 random ...
# 6          44.0  auto assigned with ignore_json=True (1 random ...
# 7          36.0  auto assigned with ignore_json=True (1 random ...
# 8          78.0  auto assigned with ignore_json=True (1 random ...
# 9          65.0  auto assigned with ignore_json=True (1 random ...
# 10          9.0  auto assigned with ignore_json=True (1 random ...
# 11         73.0  auto assigned with ignore_json=True (1 random ...
# 12          1.0  auto assigned with ignore_json=True (1 random ...
# 13         61.0  auto assigned with ignore_json=True (1 random ...
# 14         76.0  auto assigned with ignore_json=True (1 random ...
# 15         31.0  auto assigned with ignore_json=True (1 random ...
# 16         49.0  auto assigned with ignore_json=True (1 random ...
# 17         77.0  auto assigned with ignore_json=True (1 random ...
# 18         44.0  auto assigned with ignore_json=True (1 random ...
# 19         14.0  auto assigned with ignore_json=True (1 random ...
# 20         78.0  auto assigned with ignore_json=True (1 random ...
# 21         64.0  auto assigned with ignore_json=True (1 random ...
# 22          9.0  auto assigned with ignore_json=True (1 random ...
# 23          1.0  auto assigned with ignore_json=True (1 random ...
# 24         61.0  auto assigned with ignore_json=True (1 random ...
# 25         15.0  auto assigned with ignore_json=True (1 random ...
# 26         76.0  auto assigned with ignore_json=True (1 random ...
# 27         31.0  auto assigned with ignore_json=True (1 random ...
# 28         49.0  auto assigned with ignore_json=True (1 random ...
# 29         82.0  auto assigned with ignore_json=True (1 random ...
# 30         77.0  auto assigned with ignore_json=True (1 random ...
# 31         44.0  auto assigned with ignore_json=True (1 random ...
# 32         36.0  auto assigned with ignore_json=True (1 random ...
# 33         14.0  auto assigned with ignore_json=True (1 random ...
# 34         78.0  auto assigned with ignore_json=True (1 random ...
# 35         65.0  auto assigned with ignore_json=True (1 random ...
# 36         64.0  auto assigned with ignore_json=True (1 random ...
# 37          9.0  auto assigned with ignore_json=True (1 random ...
# 38         73.0  auto assigned with ignore_json=True (1 random ...
# 39         15.0  auto assigned with ignore_json=True (1 random ...
# 40         76.0  auto assigned with ignore_json=True (1 random ...
# 41         82.0  auto assigned with ignore_json=True (1 random ...
# 42         36.0  auto assigned with ignore_json=True (1 random ...
# 43         14.0  auto assigned with ignore_json=True (1 random ...
# 44         65.0  auto assigned with ignore_json=True (1 random ...
# 45         64.0  auto assigned with ignore_json=True (1 random ...
# 46         73.0  auto assigned with ignore_json=True (1 random ...
# 47          1.0  auto assigned with ignore_json=True (1 random ...
# 48         61.0  auto assigned with ignore_json=True (1 random ...
# 49         15.0  auto assigned with ignore_json=True (1 random ...
# 50          NaN                    1, df_answer_len=48, n_trials=1
